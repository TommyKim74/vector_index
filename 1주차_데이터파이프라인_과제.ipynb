# %% [markdown]
# ### Spark 설정

# %%
import glob
import pyspark
from pyspark.sql import SparkSession
conf = pyspark.SparkConf()
spark = SparkSession.builder.appName("listings").config(conf=conf).getOrCreate()

# %%
# Write the DataFrame to an Elasticsearch index
es_conf = {
    "es.nodes.discovery": "false",
    "es.nodes.data.only": "false",
    "es.net.http.auth.user": "elastic",
    "es.net.http.auth.pass": "password",
    "es.index.auto.create": "true",
    "es.nodes": "http://127.0.0.1",
    "es.port": "9200",
    "es.mapping.id": "item_id",
}

# %% [markdown]
# ### elasticsearch index batch  (특정폴더의 json 파일 색인)

# %%
def index_json_to_elasticsearch_batch(spark, directory_path):
    """
    특정 디렉토리의 JSON 파일을 순차적으로 읽고 Spark DataFrame으로 처리하는 엘라스틱서치 색인 요청
    Args:
        spark: SparkSession 객체
        directory_path: JSON 파일이 위치한 디렉토리 경로
    """    
    json_files = glob.glob(directory_path + "/*.json")

    # 각 JSON 파일을 순차적으로 색인
    for file_path in json_files:
        df = spark.read.json(file_path)
        print(f"Processing file: {file_path}")
        #df.show(n=3)
        df.write.mode("append")\
            .format('org.elasticsearch.spark.sql') \
            .options(**es_conf) \
            .save("listings")

# %%
index_json_to_elasticsearch_batch(spark, "data/")

# %%
pip install elasticsearch
# Out:
# Collecting elasticsearch
#   Downloading elasticsearch-8.15.1-py3-none-any.whl.metadata (8.7 kB)
# Collecting elastic-transport<9,>=8.13 (from elasticsearch)
#   Downloading elastic_transport-8.15.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: urllib3<3,>=1.26.2 in c:\users\tommy\appdata\local\pypoetry\cache\virtualenvs\vector-index-hyppgsn0-py3.11\lib\site-packages (from elastic-transport<9,>=8.13->elasticsearch) (2.2.3)
# Requirement already satisfied: certifi in c:\users\tommy\appdata\local\pypoetry\cache\virtualenvs\vector-index-hyppgsn0-py3.11\lib\site-packages (from elastic-transport<9,>=8.13->elasticsearch) (2024.8.30)
# Downloading elasticsearch-8.15.1-py3-none-any.whl (524 kB)
#    ---------------------------------------- 0.0/524.6 kB ? eta -:--:--
#    --------------------------------------- 524.6/524.6 kB 16.4 MB/s eta 0:00:00
# Downloading elastic_transport-8.15.1-py3-none-any.whl (64 kB)
# Installing collected packages: elastic-transport, elasticsearch
# Successfully installed elastic-transport-8.15.1 elasticsearch-8.15.1
# Note: you may need to restart the kernel to use updated packages.

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch("http://localhost:9200")  
index_name = "listings"

# %% [markdown]
# ### 인덱스의 특정 문서 업데이트

# %%
def update_product(es, index_name, doc_id, item_keywords, product_description):
    """
    인덱스의 특정 문서를 업데이트하는 함수

    Args:
        es: Elasticsearch 클라이언트 객체
        index_name: 업데이트할 인덱스 이름
        doc_id: 업데이트할 문서의 ID
        item_keywords: 새로운 키워드 리스트
        product_description: 새로운 상품 설명
    """
    
    doc = {
        "doc": {
            "item_keywords": item_keywords,
            "product_description.value": product_description
        }
    }

    # 문서 업데이트
    response = es.update(index=index_name, id=doc_id, body=doc)

    return response

# %%
doc_id = "B07RQL63MD"
item_keywords =  [
    {
      "language_tag": "en_IN",
      "value": "handwash"
    },
    {
      "language_tag": "en_IN",
      "comment": "liquid hand wash"
    }
  ]
product_description = "Solimo Handwash Liquid, Sea Minerals."

result = update_product(es,index_name, doc_id, item_keywords, product_description)
print(result)
# Out:
# {'_index': 'listings', '_id': 'B07RQL63MD', '_version': 7, 'result': 'updated', '_shards': {'total': 2, 'successful': 1, 'failed': 0}, '_seq_no': 304646, '_primary_term': 2}

# %% [markdown]
# ### 인덱스 검색 (특정 키워드를 포함하는 문서 검색)

# %%
def search_products_by_keyword(es, index_name, keyword):
  """
  인덱스 검색 (특정 키워드를 포함하는 문서 검색)
  Args:
    es: Elasticsearch 클라이언트 객체
    index_name: 검색할 인덱스 이름
    keyword: 검색할 키워드

  Returns:
    검색 결과
  """

  query = {
    "query": {
      "bool": {
        "should": [
          {"match": {"item_keywords.value": keyword}},
          {"match": {"product_description.value": keyword}}
        ]
      }
    }
  }
    
  response = es.search(index=index_name, body=query)
  return response

# %%
keyword = "mobile"
results = search_products_by_keyword(es, index_name, keyword)

# 결과 출력 (예시)
for hit in results['hits']['hits']:
  print(hit['_source'])
# Out:
# {'brand': [{'language_tag': 'de_DE', 'value': 'EONO'}], 'bullet_point': [{'language_tag': 'nl_NL', 'value': 'White board met moderne whiteboard-standaard, geavanceerde Triple-Surface-Coat Technology biedt ultra-smooth, anti-glare whiteboard afwerking die schoon maakt met één wip, bestand tegen krassen, en is getest om vrij van stains en markeerresten te blijven.'}, {'language_tag': 'nl_NL', 'value': 'Smooth-rollende wielen – het whiteboard staat gemakkelijk op harde of harde oppervlakken en de wiel vergrendelt op zijn plaats wanneer je klaar bent om te starten met de wheel slot.'}, {'language_tag': 'nl_NL', 'value': 'Schrijven More, Faster - Met een snelle aanraking van de knop op de bord, de whiteboard-flips om je binnen enkele seconden toegang te geven tot de bovenkant van het board.'}, {'language_tag': 'nl_NL', 'value': 'Inclusief alle hardware en gereedschappen voor setup, zoals twee markers en meer. Het heavy-duty frame is gemakkelijk te monteren en is ontworpen om de meest voorkomende omgevingsomgevingen te vinden in scholen, kantoren, universities, en meer.'}, {'language_tag': 'nl_NL', 'value': 'Jouw tevredenheid en happiness zijn onze hoogste prioriteit, en we hebben ons heen en weer beyond om onze whiteboards in geavanceerde multi-layer padded dozen voor maximale bescherming. Bovendien ontvang je onze Lifetime Satisfaction Guarantee. Love it or your money back!'}, {'language_tag': 'tr_TR', 'value': 'Modern Beyaz Tahta Standı ile Beyaz Tahta - Gelişmiş Üçlü Yüzey Kaplama teknolojisi ultra pürüzsüz, yansıma önleyici beyaz tahta kaplaması ile tek bir hareketle temizler, çizilmeye karşı dayanıklıdır ve leke ve işaretleme kalıntısı olmaması için test edilmiştir.'}, {'language_tag': 'tr_TR', 'value': 'Kolay dönen tekerlekler – Beyaz tahta standı sert veya halılı yüzeylere kolayca yuvarlanır ve yazmaya başladığınızda tekerlek kilidi güvenli bir şekilde yerinde durur.'}, {'language_tag': 'tr_TR', 'value': 'Daha Fazla Yazın, Daha Hızlı - Tahtanın serbest bırakma düğmesine hızlı bir şekilde dokunarak beyaz tahta saniyeler içinde ters tarafına erişmenizi sağlar.'}, {'language_tag': 'tr_TR', 'value': 'Kurulum için gerekli tüm donanım ve aletlerin yanı sıra iki marker ve silgi içerir. Ağır hizmet tipi çerçeve kolayca monte edilebilir ve okullarda, ofislerde, hastanelerde, üniversitelerde ve daha fazlasında en zorlu ortamlara dayanacak şekilde üretilmiştir.'}, {'language_tag': 'tr_TR', 'value': 'Memnuniyetiniz ve mutluluğunuz birinci önceliğimizdir ve bu nedenle beyaz tahtalarımızı maksimum koruma için güçlendirilmiş çok katmanlı dolgulu kutularda göndermeyi önceliğimizdir. Ayrıca, satın alımınızla birlikte Ömür Boyu Memnuniyet Garantisini de alacaksınız. Bunu ya da PARA İADESİ SEVİN EDİN!'}, {'language_tag': 'cs_CZ', 'value': 'White Board with Modern Whiteboard Stand - Advanced Triple-Surface-Coat technology provides an Ultra-Smooth, anti-glare whiteboard finish that erases clean with one swipe, resists scratching, and is Tested to stay free of Stains and marker residue.'}, {'language_tag': 'cs_CZ', 'value': 'Smooth-rolling Wheels – whiteboard stand rolls easily on hard or carpeted surfaces and the wheel lock securely in place writing to start.'}, {'language_tag': 'cs_CZ', 'value': 'Write More, Faster - With a quick touch of the board release button, the whiteboard flips over to give you access to the opposite side of the board in seconds.'}, {'language_tag': 'cs_CZ', 'value': 'Obsahuje kompletní příslušenství a nástroje pro setup, ať už se jedná o markers and an eraser. The Heavy Duty Frame is easy to assemble and is built to withstand the most demanding enUmwelt in schools, offices, hospitals, universities, and more.'}, {'language_tag': 'cs_CZ', 'value': "Your satisfaction and happiness are our top priority, and that's why we go above and beyond to ship our whiteboards in reinforced multi-layer padded boxes for maximum protection. Uložte si svou vlastní lásku a udělejte si svůj životní styl. LOVE IT OR YOUR MONEY BACK!"}, {'lang ...
# {'brand': [{'language_tag': 'de_DE', 'value': 'EONO'}], 'bullet_point': [{'language_tag': 'nl_NL', 'value': 'White board met moderne whiteboard-standaard, geavanceerde Triple-Surface-Coat Technology biedt ultra-smooth, anti-glare whiteboard afwerking die schoon maakt met één wip, bestand tegen krassen, en is getest om vrij van stains en markeerresten te blijven.'}, {'language_tag': 'nl_NL', 'value': 'Smooth-rollende wielen – het whiteboard staat gemakkelijk op harde of harde oppervlakken en de wiel vergrendelt op zijn plaats wanneer je klaar bent om te starten met de wheel slot.'}, {'language_tag': 'nl_NL', 'value': 'Schrijven More, Faster - Met een snelle aanraking van de knop op de bord, de whiteboard-flips om je binnen enkele seconden toegang te geven tot de bovenkant van het board.'}, {'language_tag': 'nl_NL', 'value': 'Inclusief alle hardware en gereedschappen voor setup, zoals twee markers en meer. Het heavy-duty frame is gemakkelijk te monteren en is ontworpen om de meest voorkomende omgevingsomgevingen te vinden in scholen, kantoren, universities, en meer.'}, {'language_tag': 'nl_NL', 'value': 'Jouw tevredenheid en happiness zijn onze hoogste prioriteit, en we hebben ons heen en weer beyond om onze whiteboards in geavanceerde multi-layer padded dozen voor maximale bescherming. Bovendien ontvang je onze Lifetime Satisfaction Guarantee. Love it or your money back!'}, {'language_tag': 'tr_TR', 'value': 'Modern Beyaz Tahta Standı ile Beyaz Tahta - Gelişmiş Üçlü Yüzey Kaplama teknolojisi ultra pürüzsüz, yansıma önleyici beyaz tahta kaplaması ile tek bir hareketle temizler, çizilmeye karşı dayanıklıdır ve leke ve işaretleme kalıntısı olmaması için test edilmiştir.'}, {'language_tag': 'tr_TR', 'value': 'Kolay dönen tekerlekler – Beyaz tahta standı sert veya halılı yüzeylere kolayca yuvarlanır ve yazmaya başladığınızda tekerlek kilidi güvenli bir şekilde yerinde durur.'}, {'language_tag': 'tr_TR', 'value': 'Daha Fazla Yazın, Daha Hızlı - Tahtanın serbest bırakma düğmesine hızlı bir şekilde dokunarak beyaz tahta saniyeler içinde ters tarafına erişmenizi sağlar.'}, {'language_tag': 'tr_TR', 'value': 'Kurulum için gerekli tüm donanım ve aletlerin yanı sıra iki marker ve silgi içerir. Ağır hizmet tipi çerçeve kolayca monte edilebilir ve okullarda, ofislerde, hastanelerde, üniversitelerde ve daha fazlasında en zorlu ortamlara dayanacak şekilde üretilmiştir.'}, {'language_tag': 'tr_TR', 'value': 'Memnuniyetiniz ve mutluluğunuz birinci önceliğimizdir ve bu nedenle beyaz tahtalarımızı maksimum koruma için güçlendirilmiş çok katmanlı dolgulu kutularda göndermeyi önceliğimizdir. Ayrıca, satın alımınızla birlikte Ömür Boyu Memnuniyet Garantisini de alacaksınız. Bunu ya da PARA İADESİ SEVİN EDİN!'}, {'language_tag': 'cs_CZ', 'value': 'White Board with Modern Whiteboard Stand - Advanced Triple-Surface-Coat technology provides an Ultra-Smooth, anti-glare whiteboard finish that erases clean with one swipe, resists scratching, and is Tested to stay free of Stains and marker residue.'}, {'language_tag': 'cs_CZ', 'value': 'Smooth-rolling Wheels – whiteboard stand rolls easily on hard or carpeted surfaces and the wheel lock securely in place writing to start.'}, {'language_tag': 'cs_CZ', 'value': 'Write More, Faster - With a quick touch of the board release button, the whiteboard flips over to give you access to the opposite side of the board in seconds.'}, {'language_tag': 'cs_CZ', 'value': 'Obsahuje kompletní příslušenství a nástroje pro setup, ať už se jedná o markers and an eraser. The Heavy Duty Frame is easy to assemble and is built to withstand the most demanding enUmwelt in schools, offices, hospitals, universities, and more.'}, {'language_tag': 'cs_CZ', 'value': "Your satisfaction and happiness are our top priority, and that's why we go above and beyond to ship our whiteboards in reinforced multi-layer padded boxes for maximum protection. Uložte si svou vlastní lásku a udělejte si svůj životní styl. LOVE IT OR YOUR MONEY BACK!"}, {'lang ...
# {'brand': [{'language_tag': 'de_DE', 'value': 'EONO'}], 'bullet_point': [{'language_tag': 'nl_NL', 'value': 'White board met moderne whiteboard-standaard, geavanceerde Triple-Surface-Coat Technology biedt ultra-smooth, anti-glare whiteboard afwerking die schoon maakt met één wip, bestand tegen krassen, en is getest om vrij van stains en markeerresten te blijven.'}, {'language_tag': 'nl_NL', 'value': 'Smooth-rollende wielen – het whiteboard staat gemakkelijk op harde of harde oppervlakken en de wiel vergrendelt op zijn plaats wanneer je klaar bent om te starten met de wheel slot.'}, {'language_tag': 'nl_NL', 'value': 'Schrijven More, Faster - Met een snelle aanraking van de knop op de bord, de whiteboard-flips om je binnen enkele seconden toegang te geven tot de bovenkant van het board.'}, {'language_tag': 'nl_NL', 'value': 'Inclusief alle hardware en gereedschappen voor setup, zoals twee markers en meer. Het heavy-duty frame is gemakkelijk te monteren en is ontworpen om de meest voorkomende omgevingsomgevingen te vinden in scholen, kantoren, universities, en meer.'}, {'language_tag': 'nl_NL', 'value': 'Jouw tevredenheid en happiness zijn onze hoogste prioriteit, en we hebben ons heen en weer beyond om onze whiteboards in geavanceerde multi-layer padded dozen voor maximale bescherming. Bovendien ontvang je onze Lifetime Satisfaction Guarantee. Love it or your money back!'}, {'language_tag': 'tr_TR', 'value': 'Modern Beyaz Tahta Standı ile Beyaz Tahta - Gelişmiş Üçlü Yüzey Kaplama teknolojisi ultra pürüzsüz, yansıma önleyici beyaz tahta kaplaması ile tek bir hareketle temizler, çizilmeye karşı dayanıklıdır ve leke ve işaretleme kalıntısı olmaması için test edilmiştir.'}, {'language_tag': 'tr_TR', 'value': 'Kolay dönen tekerlekler – Beyaz tahta standı sert veya halılı yüzeylere kolayca yuvarlanır ve yazmaya başladığınızda tekerlek kilidi güvenli bir şekilde yerinde durur.'}, {'language_tag': 'tr_TR', 'value': 'Daha Fazla Yazın, Daha Hızlı - Tahtanın serbest bırakma düğmesine hızlı bir şekilde dokunarak beyaz tahta saniyeler içinde ters tarafına erişmenizi sağlar.'}, {'language_tag': 'tr_TR', 'value': 'Kurulum için gerekli tüm donanım ve aletlerin yanı sıra iki marker ve silgi içerir. Ağır hizmet tipi çerçeve kolayca monte edilebilir ve okullarda, ofislerde, hastanelerde, üniversitelerde ve daha fazlasında en zorlu ortamlara dayanacak şekilde üretilmiştir.'}, {'language_tag': 'tr_TR', 'value': 'Memnuniyetiniz ve mutluluğunuz birinci önceliğimizdir ve bu nedenle beyaz tahtalarımızı maksimum koruma için güçlendirilmiş çok katmanlı dolgulu kutularda göndermeyi önceliğimizdir. Ayrıca, satın alımınızla birlikte Ömür Boyu Memnuniyet Garantisini de alacaksınız. Bunu ya da PARA İADESİ SEVİN EDİN!'}, {'language_tag': 'cs_CZ', 'value': 'White Board with Modern Whiteboard Stand - Advanced Triple-Surface-Coat technology provides an Ultra-Smooth, anti-glare whiteboard finish that erases clean with one swipe, resists scratching, and is Tested to stay free of Stains and marker residue.'}, {'language_tag': 'cs_CZ', 'value': 'Smooth-rolling Wheels – whiteboard stand rolls easily on hard or carpeted surfaces and the wheel lock securely in place writing to start.'}, {'language_tag': 'cs_CZ', 'value': 'Write More, Faster - With a quick touch of the board release button, the whiteboard flips over to give you access to the opposite side of the board in seconds.'}, {'language_tag': 'cs_CZ', 'value': 'Obsahuje kompletní příslušenství a nástroje pro setup, ať už se jedná o markers and an eraser. The Heavy Duty Frame is easy to assemble and is built to withstand the most demanding enUmwelt in schools, offices, hospitals, universities, and more.'}, {'language_tag': 'cs_CZ', 'value': "Your satisfaction and happiness are our top priority, and that's why we go above and beyond to ship our whiteboards in reinforced multi-layer padded boxes for maximum protection. Uložte si svou vlastní lásku a udělejte si svůj životní styl. LOVE IT OR YOUR MONEY BACK!"}, {'lang ...
# {'brand': [{'language_tag': 'en_GB', 'value': 'EONO'}], 'bullet_point': [{'language_tag': 'en_GB', 'value': 'White Board with Modern Whiteboard Stand - Advanced Triple-Surface-Coat technology provides an Ultra-Smooth, anti-glare whiteboard finish that erases clean with one swipe, resists scratching, and is tested to stay free of stains and marker residue.'}, {'language_tag': 'en_GB', 'value': 'Smooth-rolling Wheels – The whiteboard stand rolls easily on hard or carpeted surfaces and the wheel lock securely in place when you’re ready to start writing.'}, {'language_tag': 'en_GB', 'value': 'Write More, Faster - With a quick touch of the board release button, the whiteboard flips over to give you access to the opposite side of the board in seconds.'}, {'language_tag': 'en_GB', 'value': 'Includes all hardware and tools necessary for setup. The Heavy-Duty frame is easy to assemble and is built to withstand the most demanding environments in schools, offices, hospitals, universities, and more.'}, {'language_tag': 'en_GB', 'value': 'Your satisfaction and happiness are our top priority, and that’s why we go above and beyond to ship our whiteboards in reinforced multi-layer padded boxes for maximum protection. In addition, with your purchase, you receive our Lifetime Satisfaction Guarantee. LOVE IT OR YOUR MONEY BACK!'}], 'country': 'GB', 'domain_name': 'amazon.co.uk', 'item_id': 'B07TXLL9FX', 'item_keywords': [{'language_tag': 'en_GB', 'value': 'mobile whiteboard,rolling dry erase boards,portable whiteboard,whiteboard with stand'}], 'item_name': [{'language_tag': 'en_GB', 'value': 'EONO Whiteboard with Rolling Stand, Large 90 x 120cm Mobile Dry Erase Board with Wheels'}], 'item_weight': [{'normalized_value': {'unit': 'pounds', 'value': 39.68320716}, 'unit': 'kilograms', 'value': 18.0}], 'main_image_id': '51-9LaLBm0L', 'marketplace': 'Amazon', 'node': [{'node_id': 9469052031, 'node_name': '/Categories/Office Supplies/Presentation Supplies/Whiteboards'}], 'other_image_id': ['515dT0H3XqL', '61geRwgbOUL', '61Ss0QlFgxL', '51XMLDtoBoL', '61oQkUObeJL', '61pgAApnc+L', '61vyuzOn3aL'], 'product_description': [{'language_tag': 'en_GB', 'value': 'EOCO Whiteboard with Rolling Stand, Large 90 x 120cm Mobile Dry Erase Board with Wheels'}], 'product_type': [{'value': 'OFFICE_PRODUCTS'}]}
# {'brand': [{'language_tag': 'en_SG', 'value': 'AmazonBasics'}], 'bullet_point': [{'language_tag': 'en_SG', 'value': 'Dry-erase mobile presentation easel; ideal for presenting, teaching, advertising, drawing, score keeping, and more'}, {'language_tag': 'en_SG', 'value': 'Smooth, durable, melamine dry-erase writing surface (non-magnetic); wipes clean quickly and easily; suitable for moderate use'}, {'language_tag': 'en_SG', 'value': 'Adjustable board angle for comfortable viewing; durable MDF backing and stylish black aluminum frame'}, {'language_tag': 'en_SG', 'value': 'Strong steel base with 5 lockable casters for smooth mobility and secure placement'}, {'language_tag': 'en_SG', 'value': 'Measures 73 by 26 by 32 inches; backed by an AmazonBasics 1-year limited warranty'}], 'color': [{'language_tag': 'en_SG', 'value': 'Standing'}], 'country': 'SG', 'domain_name': 'amazon.sg', 'item_dimensions': {'height': {'normalized_value': {'unit': 'inches', 'value': 31.8}, 'unit': 'inches', 'value': 31.8}, 'length': {'normalized_value': {'unit': 'inches', 'value': 72.8}, 'unit': 'inches', 'value': 72.8}, 'width': {'normalized_value': {'unit': 'inches', 'value': 26.3}, 'unit': 'inches', 'value': 26.3}}, 'item_id': 'B07K65F46M', 'item_keywords': [{'language_tag': 'en_SG', 'value': 'tray'}, {'language_tag': 'en_SG', 'value': 'wheels'}, {'language_tag': 'en_SG', 'value': 'big'}, {'language_tag': 'en_SG', 'value': 'easel'}, {'language_tag': 'en_SG', 'value': '24x36'}, {'language_tag': 'en_SG', 'value': '48'}, {'language_tag': 'en_SG', 'value': 'earese'}, {'language_tag': 'en_SG', 'value': 'easles'}, {'language_tag': 'en_SG', 'value': 'cubicle'}, {'language_tag': 'en_SG', 'value': 'slim'}, {'language_tag': 'en_SG', 'value': '96x40'}, {'language_tag': 'en_SG', 'value': 'office'}, {'language_tag': 'en_SG', 'value': 'frameless'}, {'language_tag': 'en_SG', 'value': 'ultra'}, {'language_tag': 'en_SG', 'value': 'stands'}, {'language_tag': 'en_SG', 'value': 'magnetic'}, {'language_tag': 'en_SG', 'value': 'giant'}, {'language_tag': 'en_SG', 'value': '48"'}, {'language_tag': 'en_SG', 'value': 'glass'}, {'language_tag': 'en_SG', 'value': 'large'}, {'language_tag': 'en_SG', 'value': 'viz'}, {'language_tag': 'en_SG', 'value': 'double'}, {'language_tag': 'en_SG', 'value': '72"'}, {'language_tag': 'en_SG', 'value': 'pro'}, {'language_tag': 'en_SG', 'value': '/'}, {'language_tag': 'en_SG', 'value': 'whiteboards'}, {'language_tag': 'en_SG', 'value': '48x36'}, {'language_tag': 'en_SG', 'value': '3x4'}, {'language_tag': 'en_SG', 'value': '4'}, {'language_tag': 'en_SG', 'value': '6'}, {'language_tag': 'en_SG', 'value': 'eraser'}, {'language_tag': 'en_SG', 'value': 'ease'}, {'language_tag': 'en_SG', 'value': '24'}, {'language_tag': 'en_SG', 'value': 'game'}, {'language_tag': 'en_SG', 'value': 'hang'}, {'language_tag': 'en_SG', 'value': '28'}, {'language_tag': 'en_SG', 'value': 'boards'}, {'language_tag': 'en_SG', 'value': 'qrtg7248w'}, {'language_tag': 'en_SG', 'value': 'whiteboard'}, {'language_tag': 'en_SG', 'value': 'g7248w'}, {'language_tag': 'en_SG', 'value': 'rolling'}, {'language_tag': 'en_SG', 'value': '72'}, {'language_tag': 'en_SG', 'value': 'free'}, {'language_tag': 'en_SG', 'value': 'flip'}, {'language_tag': 'en_SG', 'value': 'on'}, {'language_tag': 'en_SG', 'value': '4x6'}, {'language_tag': 'en_SG', 'value': '6x4'}, {'language_tag': 'en_SG', 'value': '(g7248w)'}, {'language_tag': 'en_SG', 'value': 'x'}, {'language_tag': 'en_SG', 'value': 'infinity'}, {'language_tag': 'en_SG', 'value': 'chart'}, {'language_tag': 'en_SG', 'value': 'quartet'}], 'item_name': [{'language_tag': 'en_SG', 'value': 'AmazonBasics Dry Erase Mobile Presentation White Board Easel, Non-Magnetic, Black'}], 'item_weight': [{'normalized_value': {'unit': 'pounds', 'value': 17.18}, 'unit': 'pounds', 'value': 17.18}], 'main_image_id': '51sfHMvsl7L', 'marketplace': 'Amazon', 'model_number': [{'value': 'KK2454A'}], 'node': [{'node_id': 6385049051, 'node_name': '/Categories/Office Supplies/Pr ...
# {'brand': [{'language_tag': 'en_IN', 'value': 'Amazon Brand - Solimo'}], 'bullet_point': [{'language_tag': 'hi_IN', 'value': 'वॉल्यूम बटन, ऑडियो और चार्जिंग पोर्ट के लिए सही कटआउट के साथ OnePlus 5T के लिए चुस्त फिट.'}, {'language_tag': 'hi_IN', 'value': 'टिकाऊ, सॉफ़्ट और लचीला पीछे का कवर.'}, {'language_tag': 'hi_IN', 'value': 'टीयर और स्लिप-रेज़िस्टेंट.'}, {'language_tag': 'hi_IN', 'value': 'फ्लैट सतह पर गिरने पर स्क्रीन की रक्षा में मदद के लिए अपर-लिप बिल्ड डिज़ाइन किया गया है'}, {'language_tag': 'hi_IN', 'value': 'स्क्रैच, फिंगरप्रिंट और पसीने से फ़ोन की सुरक्षा करता है.'}, {'language_tag': 'hi_IN', 'value': 'आपके फ़ोन की खूबसूरती को बढ़ाने के लिए पतला पारदर्शक केस.'}, {'language_tag': 'hi_IN', 'value': 'ज्यादा इस्तेमाल के बाद भी पीला नहीं पड़ता है.'}, {'language_tag': 'hi_IN', 'value': 'लगाना और निकालना आसान है.'}, {'language_tag': 'en_IN', 'value': 'Snug fit for OnePlus 5T, with perfect cutouts for volume buttons, audio & charging ports'}, {'language_tag': 'en_IN', 'value': 'Durable, soft & flexible back case'}, {'language_tag': 'en_IN', 'value': 'Tear & slip-resistant'}, {'language_tag': 'en_IN', 'value': 'Raised upper lip build design to help protect the screen against fall on a flat surface'}, {'language_tag': 'en_IN', 'value': 'Protects phone from scratches, fingerprints and sweat'}, {'language_tag': 'en_IN', 'value': 'Slim transparent case to enhance the look of your phone'}, {'language_tag': 'en_IN', 'value': 'Does not turn yellow after extended use'}, {'language_tag': 'en_IN', 'value': 'Easy to put & take off'}], 'color': [{'language_tag': 'en_IN', 'standardized_values': ['blue'], 'value': 'Blue'}], 'country': 'IN', 'domain_name': 'amazon.in', 'item_id': 'B079J3THMN', 'item_keywords': [{'language_tag': 'en_IN', 'value': 'one plus 5t phone covers'}, {'language_tag': 'en_IN', 'value': 'oneplus 5t covers and cases'}, {'language_tag': 'en_IN', 'value': 'oneplus 5t cases'}, {'language_tag': 'en_IN', 'value': 'one plus 5t cases and covers'}, {'language_tag': 'en_IN', 'value': 'oneplus 5t cover'}, {'language_tag': 'en_IN', 'value': 'one plus 5t cover'}, {'language_tag': 'en_IN', 'value': 'oneplus 5t back cover'}, {'language_tag': 'en_IN', 'value': 'oneplus 5t case'}, {'language_tag': 'en_IN', 'value': 'one plus 5t covers'}, {'language_tag': 'en_IN', 'value': 'one plus 5t back covers'}, {'language_tag': 'en_IN', 'value': 'oneplus 5t cases and covers'}, {'language_tag': 'en_IN', 'value': 'one plus 5t case'}, {'language_tag': 'en_IN', 'value': 'one plus 5t cases'}, {'language_tag': 'en_IN', 'value': 'oneplus 5t covers'}, {'language_tag': 'en_IN', 'value': 'one plus 5t back cover'}, {'language_tag': 'en_IN', 'value': 'one plus 5t phone covers for girls'}, {'language_tag': 'en_IN', 'value': 'oneplus 5t flip covers'}, {'language_tag': 'en_IN', 'value': 'one plus 5t cover case'}, {'language_tag': 'en_IN', 'value': 'one plus 5t phone case'}, {'language_tag': 'en_IN', 'value': 'one plus 5t flip covers'}, {'language_tag': 'en_IN', 'value': 'one plus 5t phone covers silicon'}, {'language_tag': 'en_IN', 'value': 'back cover for one plus 5t'}, {'language_tag': 'en_IN', 'value': 'one plus 5 t cover'}, {'language_tag': 'en_IN', 'value': 'one plus 5t phone back cover'}, {'language_tag': 'en_IN', 'value': 'cover for one plus 5t'}, {'language_tag': 'en_IN', 'value': 'one plus 5t mobile cover'}, {'language_tag': 'en_IN', 'value': 'one plus 5t phone covers for boys'}, {'language_tag': 'en_IN', 'value': 'oneplus 5t back case'}, {'language_tag': 'en_IN', 'value': 'one plus 5t avengers case'}, {'language_tag': 'en_IN', 'value': 'oneplus 5t cases and covers designer'}, {'language_tag': 'en_IN', 'value': 'oneplus 5t bumper case'}, {'language_tag': 'en_IN', 'value': 'cases for one plus 5t'}, {'language_tag': 'en_IN', 'value': 'one plus 5t back cases'}, {'language_tag': 'en_IN', 'value': 'one plus 5t phone cover'}, {'language_tag': 'en_IN', 'value': 'one plus 5t phone covers printed'}, {'language_tag': 'en_IN', 'value': 'oneplus 5t covers and cases for  ...
# {'brand': [{'language_tag': 'de_DE', 'value': 'Eono'}], 'bullet_point': [{'language_tag': 'en_GB', 'value': 'Wide compatibility: the mobile phone ring holder is almost compatible with all smartphones in 4-8 inches, such as phone Xs Max XR X 8 8 Plus 7 7 Plus 6 6 Plus 5 5s 5c, HUAWEI, Galaxy S10 S9 S8 S7 S6 S5 S4, Note 6 5, LG, Sony, Nexus, other Android phones, although with case. (Cannot be used for wireless charging.)'}, {'language_tag': 'en_GB', 'value': '【360 degree rotation and 180 degree adjustable】The phone ring stand is characterized by a great leakage, so you can adjust and turn it over and it stays firmly fixed. It is a perfect finger ring stand in landscape or portrait mode for reading, watching videos.'}, {'language_tag': 'en_GB', 'value': '【DURABLE ADHESIVE】 Adhesive is extremely sticky, which holds the phone and prevents phone from dropping on many occasions. (Note: Use the stand for 24 hours after the bell holder attached to the phone. Clean the area (recommended on smooth and flat surfaces) where the ring holder is attached before use.'}, {'language_tag': 'en_GB', 'value': 'High quality materials: the finger ring holder for mobile phone is made of high-quality zinc alloy and stainless steel. Zinc alloy has good ductility and has toughness which contributes to a long service life. Polished ring holder, smooth edge, no worry about scratches on your fingers.'}, {'language_tag': 'en_GB', 'value': '【Multi-function】It can be used as a phone handle, table kickstand and cable winder. Besides, put it on a magnetic car mount while driving and it will also work. With one finger, hold your phone with one hand greatly reduce the risk of accidentally falling.'}, {'language_tag': 'de_DE', 'value': '【Breite Kompatibilität】 Der Handy Ringhalter ist fast kompatibel mit allen Smartphones in 4-8 Zoll, wie zum Beispiel iPhone 11, iPhone 11 Pro, iPhone 11 Pro Max, Phone Xs Max XR X 8 8 plus 7 7 plus 6 6 plus 5 5s 5c, HUAWEI, Galaxy S10 S9 S8 S7 S6 S5 S4, Hinweis 6 5 , LG, Sony, Nexus, Andere Android-Handys, obwohl mit Etui. (Kann nicht für drahtloses Laden verwendet werden.)'}, {'language_tag': 'de_DE', 'value': '【360 ° Drehung und 180 ° einstellbar】 Der Telefon Ring-Ständer zeichnet sich durch eine große Dichtigkeit aus, so dass Sie ihn einstellen und umdrehen können und er bleibt fest fixiert. Es ist ein perfekter Fingerring Ständer im Landschafts-oder Porträtmodus zum Lesen, Videos anschauen.'}, {'language_tag': 'de_DE', 'value': '【Robuster Klebstoff】 Klebstoff ist extrem klebrig, wodurch das Telefon festgehalten wird und bei vielen Gelegenheiten das Herunterfallen des Telefons verhindert wird. (Hinweis: Verwenden Sie den Ständer nach dem am Telefon angebrachten Klingelhalter 24 Stunden lang. Reinigen Sie den Bereich (empfohlen auf glatten und ebenen Flächen), wo der Ringhalter vor der Verwendung angebracht ist.'}, {'language_tag': 'de_DE', 'value': '【HochWertige Materialien】Der Fingerring Halter für Handy ist aus hochwertiger Zinklegierung und Edelstahl gefertigt. Zinklegierung hat eine gute Duktilität und verfügt über Robustheit, die zu einer langen Lebensdauer beiträgt. Polierter Ringhalter, glatte Kante, keine Sorge um Kratzer an den Fingern.'}, {'language_tag': 'de_DE', 'value': '【Multi-Funktionen】Es kann als Telefon Griff, Tisch kickstand und Kabelwickler verwendet werden. Außerdem, legen Sie es auf eine Magnet-Auto-Halterung während der Fahrt und es wird auch funktionieren. Mit einem Finger besetzt, halten Sie Ihr Telefon mit einer Hand stark reduzieren das Risiko von versehentlich fallen.'}], 'color': [{'language_tag': 'en_GB', 'standardized_values': ['silver'], 'value': 'Silver'}, {'language_tag': 'de_DE', 'standardized_values': ['Silber'], 'value': 'Silber'}], 'country': 'DE', 'domain_name': 'amazon.de', 'item_id': 'B07V9NTK8M', 'item_keywords': [{'language_tag': 'de_DE', 'value': 'Halter^Ringhalter^Telefonringhalter^Telefonschleife^Handy-Schleife^Ringständer'}], 'item_name': [{'language_tag': 'en_GB', 'value': 'Eono Es ...
# {'brand': [{'language_tag': 'en_GB', 'value': 'HIKARO'}], 'bullet_point': [{'language_tag': 'en_GB', 'value': "Versatile: Whether you're skiing, hiking, jogging, or going to the grocery store quickly, Hikaro gloves keep your hands warm while maintaining your sense of style"}, {'language_tag': 'en_GB', 'value': "Comfort: Due to the elastic knit material, our women's glove adapts perfectly to every hand. The wristband gently hugs the wrist and prevents the harsh wind and cold of Winter from penetrating."}, {'language_tag': 'en_GB', 'value': 'Fashionable: For that little extra extra shine in the gloomy winter, we have carefully integrated metal details into the fabric. A guaranteed eye-catcher, whether in everyday life or in the office'}, {'language_tag': 'en_GB', 'value': '97% acrylic, 2% metal – soft to the touch'}, {'language_tag': 'en_GB', 'value': 'one Size'}], 'color': [{'language_tag': 'en_GB', 'standardized_values': ['Grey'], 'value': 'Mid Grey'}], 'color_code': ['#555555'], 'country': 'GB', 'domain_name': 'amazon.co.uk', 'item_id': 'B08438Y2FY', 'item_keywords': [{'language_tag': 'en_GB', 'value': 'gloves ladies, gloves ladies winter, gloves black, black gloves, ski gloves, gloves winter, winter gloves, thin gloves, ladies gloves winter, girls gloves, ladies gloves knitted, ladies gloves warm'}], 'item_name': [{'language_tag': 'en_GB', 'value': 'HIKARO Women Knitted Gloves – Womens Gloves with Polyacrylic-Mix – Warm & Soft – Perfect for Fall & Winter – elegant Monochrome'}], 'main_image_id': '91qd3XgnttL', 'marketplace': 'Amazon', 'product_description': [{'language_tag': 'en_GB', 'value': 'Good mood in autumn/winter: Our plain knitted gloves provide a pleasant and natural wearing experience. The monochrome gloves have a special fabric sewn into the thumb and index finger so that the touch display of the mobile phone can be operated without having to take off the glove.'}], 'product_type': [{'value': 'ACCESSORY'}]}
# {'brand': [{'language_tag': 'en_GB', 'value': 'HIKARO'}], 'bullet_point': [{'language_tag': 'en_GB', 'value': "Versatile: Whether you're skiing, hiking, jogging, or going to the grocery store quickly, Hikaro gloves keep your hands warm while maintaining your sense of style"}, {'language_tag': 'en_GB', 'value': "Comfort: Due to the elastic knit material, our women's glove adapts perfectly to every hand. The wristband gently hugs the wrist and prevents the harsh wind and cold of Winter from penetrating."}, {'language_tag': 'en_GB', 'value': 'Fashionable: For that little extra extra shine in the gloomy winter, we have carefully integrated metal details into the fabric. A guaranteed eye-catcher, whether in everyday life or in the office'}, {'language_tag': 'en_GB', 'value': '97% acrylic, 2% metal – soft to the touch'}, {'language_tag': 'en_GB', 'value': 'one Size'}], 'color': [{'language_tag': 'en_GB', 'standardized_values': ['Red'], 'value': 'Brick'}], 'color_code': ['#56070C'], 'country': 'GB', 'domain_name': 'amazon.co.uk', 'item_id': 'B08439D7NF', 'item_keywords': [{'language_tag': 'en_GB', 'value': 'gloves ladies, gloves ladies winter, gloves black, black gloves, ski gloves, gloves winter, winter gloves, thin gloves, ladies gloves winter, girls gloves, ladies gloves knitted, ladies gloves warm'}], 'item_name': [{'language_tag': 'en_GB', 'value': 'HIKARO Women Knitted Gloves – Womens Gloves with Polyacrylic-Mix – Warm & Soft – Perfect for Fall & Winter – elegant Monochrome'}], 'main_image_id': '81K7cWxYqQL', 'marketplace': 'Amazon', 'product_description': [{'language_tag': 'en_GB', 'value': 'Good mood in autumn/winter: Our plain knitted gloves provide a pleasant and natural wearing experience. The monochrome gloves have a special fabric sewn into the thumb and index finger so that the touch display of the mobile phone can be operated without having to take off the glove.'}], 'product_type': [{'value': 'ACCESSORY'}]}
# {'brand': [{'language_tag': 'ja_JP', 'value': 'Eono(イオーノ)'}], 'bullet_point': [{'language_tag': 'zh_CN', 'value': '比其他厂家的压倒性品质：优点一：指甲宽度扩大，即使在普通的套子上也能登载。 优点二：附带备用贴纸。 防滑贴片拆下也可以自行更换。'}, {'language_tag': 'zh_CN', 'value': '【对应机型】约4-8英寸的机型(iPhone XS XS Max XR X 8 7 7plus 6 6s 6plus 5 5s 4，Samsung S3 S4 S5 S6 S7, Galaxy S7 S6, Note 6 5, LG, Sony)对应。 如果装上保护套，厚度14mm以下，可以使用。'}, {'language_tag': 'zh_CN', 'value': '（防滑）橡胶防滑垫牢固固定，稳固地固定，不会给您带来最好的视角，防止手机划伤。'}, {'language_tag': 'zh_CN', 'value': '【充电一边使用】 独创的设计、带有电缆的孔，可以在车载终端状态下充电。 简洁的孔位，方便性和美观。'}, {'language_tag': 'zh_CN', 'value': '适用多种场合：适用于厨房、办公桌、卧桌、餐桌、餐桌、餐桌。 在工作中也可以确认邮件或信息接收，非常方便。 在享受动画、电影、电子书阅读的休闲时也能大显身手。'}, {'language_tag': 'ja_JP', 'value': '👉【他メーカーより圧倒的な品質】利点一：爪の幅が広げられ、普通のカバーをつけたままでも載せられます。利点二：予備のシールがついています。滑り止めシールがずれても自分で交換できます。'}, {'language_tag': 'ja_JP', 'value': '👉【対応機種】約4－8インチの機種（iPhone XS XS Max XR X 8 7 7plus 6 6s 6plus 5 5s 4 ,Samsung S3 S4 S5 S6 S7, Galaxy S7 S6, Note 6 5, LG, Sony）に対応できる。保護ケースをつける場合、厚さが14mm以下であれば利用可能。'}, {'language_tag': 'ja_JP', 'value': '👉【滑り止め】ゴム製の滑り止めパッドによりしっかりと固定できるから、安定で最高の視野角を与えるばかりでなく、ご端末を保護し、傷つけにくくなる。'}, {'language_tag': 'ja_JP', 'value': '👉【充電しながら利用可能】 独創的な設計で、ケーブルを通すホール付き、ご端末を載せたまま充電できます。シンプルなホールにより、使いやすさと美しさを両立させます。'}, {'language_tag': 'ja_JP', 'value': '👉【多様な場面に対応できる】キッチン・オフィスデスク・ナイトテーブル・食卓に適用。仕事中でもメールやメッセージ受信を確認できるのでとても便利。アニメ、映画、電子書籍を楽しむというようなレジャーの時にも活躍しています。'}, {'language_tag': 'en_US', 'value': '(Overwhelming Quality from Other Manufacturers) Advantage 1: The width of the nails is expanded, so you can place it with a regular cover on. Advantage 2: Comes with spare stickers. If the anti-slip sticker does not move, you can replace it by yourself.'}, {'language_tag': 'en_US', 'value': '[Compatible models] Approximately 4 - 8 inches (iPhone XS XS XS Max XR X 8 7 7 Plus 6 6s 6 plus 5 5s 4 Samsung S3 S4 S5 S6 S7, Galaxy S7 S6, Note 6 5, LG, Sony). If you are wearing a protective case, you can use it if the thickness is smaller than 14mm.'}, {'language_tag': 'en_US', 'value': '(Anti-Slip) The rubber anti-slip pads can be firmly secured to provide a stable and best viewing angle, but also protect your device and prevent scratches.'}, {'language_tag': 'en_US', 'value': '(Can be used while charging) The creative design has a hole that allows the cable to pass through, so you can charge your device while you are on it. The simple holes combine ease of use and beauty.'}, {'language_tag': 'en_US', 'value': '(Suitable for Various Occasions) Suitable for kitchens, office desks, nighttables, and dining tables. It is very convenient for you to check email and receive messages while at work. Great for leisure activities like anime, movies, and e-books.'}], 'color': [{'language_tag': 'zh_CN', 'standardized_values': ['黑色'], 'value': '黑色'}, {'language_tag': 'ja_JP', 'value': '黒'}], 'country': 'JP', 'domain_name': 'amazon.co.jp', 'item_id': 'B089SLXVHF', 'item_keywords': [{'language_tag': 'ja_JP', 'value': 'タブレット kindle スマホスタンド ipod fire tv hd キンドル iphonex ケース 携帯充電器 アイパッド 携帯電話 モンスト テレビスタンド タブレットスタンド ゲーム機 タブレットホルダー tablet android アーム 車载 携帯 ワイヤレス充電 角度 じてんしゃ マグネット小型 くびかけ'}], 'item_name': [{'language_tag': 'zh_CN', 'value': '[Amazon品牌] Eono（Eono） 智能手机 支架 支架 支架 : 桌上 充电智能手机 手机, 智能手机, 智能手机, 苹果桌座, Switch 对应 丝带 iPhone 11 Pro Max Pro Max Max XS Max XR X 8 plus 7 6s 5 5s, Xiaomi Redmi huawei, Sony Xperia'}, {'language_tag': 'ja_JP', 'value': '[Amazonブランド] Eono(イオーノ) スマホ スタンド ホルダー : 卓上 充電スマホ 携帯電話, スマフォ, アイフォンデスク置き台, Switch 対応 アンドロイド, iPhone 11 Pro Max プロ マックス XS Max XR X 8 plus 7 6s 5 5s, Xiaomi Redmi huawei, Sony Xperia'}, {'language_tag': 'en_US', 'value': '[Amazon Brand] Eono Smartphone Stand Holder: Desktop Charging Smartphone Mobile Phone, Smartphone, iPhone Desk Stand, Switch Compatible Android, iPhone 11 Pro Max XS Max XR X 8 Plus 7 6s 5 5s, Xiaomi Redmi Huawei, Sony Xperia'}], 'main_image_id': '61UlNTzo+qL', 'marketplace': 'Amazon', 'model_number': [{'value': 'Eono-S-JP-B'}], 'node': [{'node_id': 2221837051, 'node_name': '/カテゴリー別/PCアクセサリ・サプライ/タブレットアクセサリ/スタンド'}], 'o ...
